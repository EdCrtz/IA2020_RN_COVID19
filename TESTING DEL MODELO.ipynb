# %%
from sklearn.externals import joblib
import pandas as pd
import numpy as np

# %%
clf = joblib.load('modelo entrenado.pkl')

# %%
newdatacsv=pd.read_csv("new_data.csv")

# %%
newdatacsv
# Out:
#    ORIGEN  EDAD  SECTOR  ENTIDAD_UM  SEXO  ENTIDAD_NAC  ENTIDAD_RES  \
# 0       2    82       3           2     1            2            2
# 1       2    72       2          12     1           12           12
# 2       2    92       2          14     1           14           14
# 3       2    60       4          27     2           27           27
# 4       2    78       4          27     2           27           27
# 5       2    53       4          21     1           21           21
#
#    MUNICIPIO_RES  TIPO_PACIENTE  INTUBADO  ...  DIABETES  EPOC  ASMA  \
# 0              2              2         2  ...         1     1     1
# 1              1              1         1  ...         1     1     2
# 2            120              1        97  ...         1     1     1
# 3              4              1        97  ...         2     2     1
# 4              4              1        97  ...         1     2     1
# 5            114              1         1  ...         1     1     1
#
# ...

# %%
new_data = np.array(newdatacsv)
results = clf.predict(new_data)
print(results)
# Out:
# [[0.27662495]
#  [0.33673918]
#  [0.0156737 ]
#  [0.0156737 ]
#  [0.0156737 ]
#  [0.30939665]]
